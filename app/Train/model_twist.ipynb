# %%
import cv2
import torch
import pandas as pd

# %%
dataset = pd.read_csv(r'D:\git_project\workshop_lifting\dataset_test.csv')
dataset
# Out:
#             time  keypoint_0_x  keypoint_0_y  keypoint_0_z  \
# 0       0.033333      0.515828      0.155126     -0.421946
# 1       0.066667      0.515788      0.155142     -0.397007
# 2       0.100000      0.516128      0.153465     -0.388880
# 3       0.133333      0.516508      0.148581     -0.373907
# 4       0.166667      0.516677      0.146597     -0.357890
# ...          ...           ...           ...           ...
# 3870  129.033333      0.632070      0.116090     -0.308916
# 3871  129.066667      0.632842      0.116782     -0.327407
# 3872  129.100000      0.634167      0.116625     -0.321632
# 3873  129.133333      0.635579      0.114117     -0.317998
# 3874  129.166667      0.637305      0.111005     -0.323740
#
#       keypoint_0_visibility  keypoint_1_x  keypoint_1_y  keypoint_1_z  \
# 0                  0.998586      0.517080      0.139846     -0.410176
# 1                  0.998637      0.517016      0.139877     -0.387344
# ...

# %%
'''
H:M:S:SS
00:02.08 - 00:03.43 ;ยก
00:03.44 - 00:04.79 ;ถือของ
00:04.80 - 00:05.73 ;วาง
00:05.74 - 00:07.66 ;ไม่ถือของ
00:07.67 - 00:08.60 ;ยก
00:08.61 - 00:11.37 ;ถือของ
00:11.38 - 00:12.45 ;วาง
00:12.46 - 00:14.20 ;ไม่ถือของ
00:14.21 - 00:16.13 ;ยก
00:16.14 - 00:20.96 ;ถือของ
00:20.97 - 00:22.71 ;วาง
00:22.72 - 00:25.53 ;ไม่ถือของ
00:25.54 - 00:27.42 ;ยก
00:27.43 - 00:30.37 ;ถือของ
00:30.38 - 00:31.85 ;วาง
00:31.86 - 00:34.68 ;ไม่ถือของ
00:34.69 - 00:36.15 ;ยก
00:36.16 - 00:40.72 ;ถือของ
00:40.73 - 00:41.72 ;วาง
00:41.73 - 00:45.45 ;ไม่ถือของ
00:45.46 - 00:47.20 ;ยก
00:47.21 - 00:51.23 ;ถือของ
00:51.24 - 00:52.98 ;วาง
00:52.99 - 00:57.28 ;ไม่ถือของ
00:57.29 - 00:58.31 ;ยก
00:58.32 - 01:01.26 ;ถือของ
01:01.27 - 01:02.31 วาง
01:02.32 - 01:09.48 ไม่ถือของ
01:09.49 - 01:11.02 ยก
01:11.03 - 01:16.94 ถือ
01:16.95 - 01:18.46 วาง
01:18.47 - 01:23.07 ไม่ถือของ
01:23.08 - 01:25.02 ยก
01:25.03 - 01:30.81 ถือ
01:30.81 - 01:31.47 วาง
01:31.48 - 01:34.71 ไม่ถือของ
01:34.72 - 01:36.79 ยก
01:36.80 - 01:40.94 ถือ
01:40.95 - 01:41.72 วาง
01:41.73 - 01:45.59 ไม่ถือของ
01:46.00 - 01:47.34 ยก
01:47.35 - 01:51.32 ถือ
01:51.53 - 01:52.90 วาง
01:52:91 - 01:56.44 ไม่ถือของ
01:56.45 - 01:58.54 ยก
01:58.55 - 02:03.48 ถือ
02:03.49 - 02:04.51 วาง
'''
